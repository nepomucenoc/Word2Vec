# %% [markdown]
# <a href="https://colab.research.google.com/github/nepomucenoc/Word2Vec/blob/main/word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Word2Vec implementation with python

# %%
import nltk
import urllib
import bs4 as bs
import re
from gensim.models import Word2Vec
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
source = urllib.request.urlopen('https://en.wikipedia.org/wiki/Global_warming')

soup = bs.BeautifulSoup(source, 'lxml')
text = ""
for paragraph in soup.find_all('p'):
    text+= paragraph.text

# %%
text
# Out:
# '\n\t\t\t\tpage  for logge  out e itor  learn more\n\n\n\nin common u age, climate change  e cribe  global warming—the ongoing increa e in global average temperature—an  it  effect  on earth\'  climate  y tem. climate change in a broa er  en e al o inclu e  previou  long-term change  to earth\'  climate. the current ri e in global average temperature i  more rapi  than previou  change , an  i  primarily cau e  by human  burning fo il fuel .   fo il fuel u e,  efore tation, an   ome agricultural an  in u trial practice  increa e greenhou e ga e , notably carbon  ioxi e an  methane.  greenhou e ga e  ab orb  ome of the heat that the earth ra iate  after it warm  from  unlight. larger amount  of the e ga e  trap more heat in earth\'  lower atmo phere, cau ing global warming.\n ue to climate change,  e ert  are expan ing, while heat wave  an  wil fire  are becoming more common.  increa e  warming in the arctic ha  contribute  to melting permafro t, glacial retreat an   ea ice lo .  highe
# ...

# %%
text = re.sub(r'[[0-9]*]', ' ', text)
text = re.sub(r's+', ' ', text)
text = text.lower()
text = re.sub(r'[_@#$%&*()<>"`:;,.e][-]',' ', text)
text = re.sub(r'd', ' ', text)
text = re.sub(r"'", ' ', text)
text = re.sub(r's+', ' ', text)

# %%
sentences = nltk.sent_tokenize(text)

sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

# %%
sentences
# Out:
# [['page',
#   'for',
#   'logge',
#   'out',
#   'e',
#   'itor',
#   'learn',
#   'more',
#   'in',
#   'common',
#   'u',
#   'age',
#   ',',
#   'climate',
#   'change',
#   'e',
#   'cribe',
#   'global',
#   'warming—the',
#   'ongoing',
#   'increa',
#   'e',
#   'in',
#   'global',
#   'average',
#   'temperature—an',
#   'it',
#   'effect',
#   'on',
#   'earth',
#   'climate',
#   'y',
#   'tem',
#   '.'],
#  ['climate',
#   'change',
#   'in',
#   'a',
#   'broa',
#   'er',
#   'en',
#   'e',
#   'al',
#   'o',
#   'inclu',
#   'e',
#   'previou',
#   'long-term',
#   'change',
#   'to',
#   'earth',
#   'climate',
#   '.'],
#  ['the',
#   'current',
#   'ri',
#   'e',
#   'in',
#   'global',
#   'average',
#   'temperature',
#   'i',
#   'more',
#   'rapi',
#   'than',
#   'previou',
#   'change',
#   ',',
#   'an',
#   'i',
#   'primarily',
#   'cau',
#   'e',
#   'by',
#   'human',
#   'burning',
#   'fo',
#   'il',
#   'fuel',
#   '.'],
#  ['fo',
#   'il',
#   'fuel',
# ...

# %%
for i in range(len(sentences)):
    sentences[i] = [word for word in sentences[i] if word not in stopwords.words('english')]

# %%
model = Word2Vec(sentences, min_count=1)
model
# Out:
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
words = model.wv.vocab
words
# Out:
# {'page': <gensim.models.keyedvectors.Vocab at 0x7f5f66a75e50>,
#  'logge': <gensim.models.keyedvectors.Vocab at 0x7f5f66a75940>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x7f5f66a75af0>,
#  'itor': <gensim.models.keyedvectors.Vocab at 0x7f5f66a75d90>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x7f5f66a75c70>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x7f5f66a75880>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x7f5f66a75bb0>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f5f66a75f70>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7f5f66a75400>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x7f5f679433d0>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7f5f67943eb0>,
#  'cribe': <gensim.models.keyedvectors.Vocab at 0x7f5f66a3ad00>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x7f5f66a3a190>,
#  'warming—the': <gensim.models.keyedvectors.Vocab at 0x7f5f66a3a040>,
#  'ongoing': <gensim.models.keyedvectors.Vocab at 0x7f5f66a3a580>,
# ...

# %%
vector = model.wv['global']
vector
# Out:
# array([-0.00703133,  0.01263127, -0.00258824, -0.01666985, -0.02215178,
#        -0.02874733,  0.00371995, -0.0029479 ,  0.01899462, -0.01494161,
#        -0.01827368,  0.04529004, -0.02043546, -0.01592247, -0.03014974,
#        -0.00799324, -0.01386947,  0.01140861, -0.00532642, -0.00968264,
#        -0.03249488, -0.00458482,  0.00539229, -0.01933333,  0.03496679,
#         0.01893803,  0.0113197 ,  0.00798804,  0.00406417,  0.00601734,
#         0.01196316, -0.00851436, -0.02141338, -0.00497355, -0.02218807,
#        -0.05156164,  0.00278134,  0.03029224, -0.04389984,  0.01382594,
#        -0.02545858,  0.01123609, -0.01114603,  0.00313856, -0.00529832,
#        -0.01334962,  0.04858409, -0.00437228, -0.00835322,  0.02961843,
#         0.0070266 ,  0.01495062,  0.01748576, -0.04001565,  0.00981653,
#         0.02334487, -0.00421837,  0.03425157,  0.02962469, -0.03523999,
#         0.02146204, -0.01230557, -0.01075077,  0.03632411,  0.04847499,
# ...

# %%
similar = model.wv.most_similar('global')
similar
# Out:
# [('e', 0.9880565404891968),
#  (',', 0.9879626035690308),
#  ('.', 0.984853208065033),
#  ('woul', 0.9831905961036682),
#  ('change', 0.9831117987632751),
#  ('ing', 0.9827107191085815),
#  ('u', 0.9823113679885864),
#  ('climate', 0.9821903705596924),
#  ('ion', 0.9813525676727295),
#  ('energy', 0.9808216094970703)]
